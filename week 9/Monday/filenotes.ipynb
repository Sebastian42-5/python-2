# %% [markdown]
# 0 = beginning
# 1 = middle
# 2 = end
#
# input_file.seek(0, 0)
#
# input.readline()
#
# input_file = open('word.txt', 'r')
# >>> for line in input_file:
# ...     input_file.readline().rstrip()
#
#
# with the write mode, it's overwriting what you already had by default
#
# $ python -i
# Python 3.12.6 (tags/v3.12.6:a4a2d2b, Sep  6 2024, 20:11:23) [MSC v.1940 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>> output_file = open('blah.txt', 'w')
# >>> output_file.write('hello')
# 5
# >>> output_file.write('abc')
# 3
# >>> output_file.write('def')
# 3
# >>> output_file.close()
# >>> output_file.open('blah.txt', 'w')
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# AttributeError: '_io.TextIOWrapper' object has no attribute 'open'
# >>> output_file = open('blah.txt', 'w')
# >>> output-file.write('abc\n')
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# NameError: name 'output' is not defined
# >>> output_file.write('abc\n')
# 4
# >>> output_file.write('def\n')
# 4
# >>> output_file.close()
# >>> output_file = open('blah.txt', 'w')
# >>> num = 1233
# >>> output_file.write(str(num) + '\n')
#   File "<stdin>", line 1
#     output_file.write(str(num) + '\n')
#                                ^
# SyntaxError: invalid non-printable character U+001B
# >>> output_file.write(str(num) + '\n')
# 5
# >>> output_file.close()
# >>> file = open('blah.txt', 'r+')
# >>> output_file = open('blah.txt', 'a')
# >>> output_file.write('hello\n')
# 6
# >>> output_file.write('abc\n')
# 4
# >>> output_file.close()
# >>> import os
# >>> os.rename('blah.txt', 'blah.out')
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# PermissionError: [WinError 32] Le processus ne peut pas acc▒der au fichier car ce fichier est utilis▒ par un autre processus: 'blah.txt' -> 'blah.out'
# >>> os.rename('word.txt', 'word.out')
# >>>

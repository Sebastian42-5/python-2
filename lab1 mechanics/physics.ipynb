# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
df=pd.read_csv("clean_data_many_filter.csv")
lst=[]

for x in range(10):

    lst.append(df.iloc[0,10+x])

print(sum(lst)/10)

[-1.05576923,
-1.03461538,
-1.13115385,  
-1.15730769, 
-1.11461538,  
-1.05423077,  
-1.01923077,  
-1.06884615,  
-1.05653846,  
-1.03846154] 

position=df.loc[:,"Position (m) Run #3"]
time=df.loc[:,"Time (s) Run #3"]
print(data)
plt.plot(time,position)
# Out:
# 1.2889999999999997
# 0     1.40
# 1     1.39
# 2     1.36
# 3     1.34
# 4     1.32
#       ...
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# Name: Position (m) Run #3, Length: 69, dtype: float64

# %%
Velocity=[-1.05576923,
-1.03461538,
-1.13115385,  
-1.15730769, 
-1.11461538,  
-1.05423077,  
-1.01923077,  
-1.06884615,  
-1.05653846,  
-1.03846154] 
averageV=sum(Velocity)/10
averageV
# Out:
# -1.0730769219999998

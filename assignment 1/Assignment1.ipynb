# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

first_experiment_df = pd.read_csv('Coffee Filter 1.csv')
second_experiment_df = pd.read_csv('Coffee Filter 2.csv')


first_experiment_df
# Out:
#     Time (s) Run #2  Position (m) Run #2  Velocity (m/s) Run #2  \
# 0              0.00                 1.47                    NaN
# 1              0.02                 1.48                  -0.45
# 2              0.04                 1.45                  -0.20
# 3              0.06                 1.46                  -0.21
# 4              0.08                 1.46                  -0.22
# ..              ...                  ...                    ...
# 89              NaN                  NaN                    NaN
# 90              NaN                  NaN                    NaN
# 91              NaN                  NaN                    NaN
# 92              NaN                  NaN                    NaN
# 93              NaN                  NaN                    NaN
#
#     Acceleration (m/s²) Run #2  Time (s) Run #3  Position (m) Run #3  \
# 0                          NaN             0.00                 1.40
# 1                          NaN             0.02                 1.39
# 2                         6.06             0.04                 1.36
# 3                         0.51             0.06                 1.34
# 4                        -1.39             0.08                 1.32
# ..                         ...              ...                  ...
# 89                         NaN              NaN                  NaN
# 90                         NaN              NaN                  NaN
# 91                         NaN              NaN                  NaN
# 92                         NaN              NaN                  NaN
# 93                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #3  Acceleration (m/s²) Run #3  Time (s) Run #4  \
# 0                     NaN                         NaN             0.00
# 1                   -0.94                         NaN             0.02
# 2                   -1.07                       -3.08             0.04
# 3                   -1.06                       -3.74             0.06
# 4                   -1.09                       -7.69             0.08
# ..                    ...                         ...              ...
# 89                    NaN                         NaN              NaN
# 90                    NaN                         NaN              NaN
# 91                    NaN                         NaN              NaN
# 92                    NaN                         NaN              NaN
# 93                    NaN                         NaN              NaN
#
#     Position (m) Run #4  ...  Velocity (m/s) Run #9  \
# 0                  1.42  ...                    NaN
# 1                  1.43  ...                   0.01
# 2                  1.43  ...                   0.05
# 3                  1.41  ...                   0.14
# 4                  1.40  ...                   0.04
# ..                  ...  ...                    ...
# 89                  NaN  ...                    NaN
# 90                  NaN  ...                    NaN
# 91                  NaN  ...                    NaN
# 92                  NaN  ...                    NaN
# 93                  NaN  ...                    NaN
#
#     Acceleration (m/s²) Run #9  Time (s) Run #10  Position (m) Run #10  \
# 0                          NaN              0.00                  1.34
# 1                          NaN              0.02                  1.35
# 2                         3.01              0.04                  1.35
# 3                        -0.34              0.06                  1.36
# 4                        -2.62              0.08                  1.35
# ..                         ...               ...                   ...
# 89                         NaN               NaN                   NaN
# 90                         NaN               NaN                   NaN
# 91                         NaN               NaN                   NaN
# 92                         NaN               NaN                   NaN
# 93                         NaN               NaN                   NaN
#
#     Velocity (m/s) Run #10  Acceleration (m/s²) Run #10  Time (s) Run #11  \
# 0                      NaN                          NaN              0.00
# 1                     0.07                          NaN              0.02
# 2                     0.10                        -2.10              0.04
# 3                    -0.01                        -4.60              0.06
# 4                    -0.11                        -6.02              0.08
# ..                     ...                          ...               ...
# 89                     NaN                          NaN              1.78
# 90                     NaN                          NaN              1.80
# 91                     NaN                          NaN              1.82
# 92                     NaN                          NaN              1.84
# 93                     NaN                          NaN              1.86
#
#     Position (m) Run #11  Velocity (m/s) Run #11  Acceleration (m/s²) Run #11
# 0                   1.36                     NaN                          NaN
# 1                   1.36                   -0.07                          NaN
# 2                   1.36                    0.12                         5.08
# 3                   1.37                    0.13                        -0.30
# 4                   1.36                    0.02                        -1.70
# ..                   ...                     ...                          ...
# 89                  1.36                   -0.05                        -0.93
# 90                  1.36                   -0.08                         0.51
# 91                  1.35                   -0.06                          NaN
# 92                  1.35                    0.06                          NaN
# 93                  1.35                     NaN                          NaN
#
# [94 rows x 40 columns]

# %% [markdown]
# - In this assignment, we have to clean up the data

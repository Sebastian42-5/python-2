# %% [markdown]
# **420-SF2-RE: DS & OOP**
#
# **February 12, 2025**

# %% [markdown]
# # Assignment #1: drag with coffee filters
#
# For this assignment you will be allowed to use everything that has been covered in class regarding data science libraries.  **Any functions not covered in class will not be allowed to be used and will receive a grade of 0**.
#
# ${\color{red}\text{You should not be making any direct changes to your .csv files.}}\\$
# ${\color{red}\text{All changes done in this assignment must be done using Python code.}}$

# %% [markdown]
# ## Part 1: experiment with single coffee filter, 10 runs
# **Part 1 DUE DATE: end of class today**
#
# **Part 1 is worth 60% of Assignment #1**
#
# **Part 1 of the assignment is an in-class assignment.  Failure to be in class will receive a grade of 0 for Part 1 of the assignment and late submissions will not be accepted.**
#
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - Late submissions of Part 1 (that is, submissions outside of class) will receive a ${\color{red}\text{late penalty}}$. Part 1 may not be submitted later than **Wendesday, February 12 ay 23:59**.
#
# #### Instructions for Part 1:

# %% [markdown]
# 1. Import all necessary libraries, such as `pandas`, `matplotlib.pyplot`, `numpy`, etc.

# %%
# your code for step 1 goes here:

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 2. Read  your `.csv` file that has the data of the single filter experiment into a DataFrame called `df`
# 3. Display the content of the data frame to the screen

# %%
# your code for steps 2 and 3 go here:

second_experiment_df = pd.read_csv('Coffee Filter 2.csv') 

second_experiment_df
# Out:
#     Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0              0.00                 1.23                    NaN
# 1              0.02                 1.21                  -0.61
# 2              0.04                 1.20                  -0.65
# 3              0.06                 1.19                  -0.68
# 4              0.08                 1.17                  -0.70
# ..              ...                  ...                    ...
# 90              NaN                  NaN                    NaN
# 91              NaN                  NaN                    NaN
# 92              NaN                  NaN                    NaN
# 93              NaN                  NaN                    NaN
# 94              NaN                  NaN                    NaN
#
#     Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                          NaN             0.00                 1.34
# 1                          NaN             0.02                 1.34
# 2                        -1.85             0.04                 1.33
# 3                        -1.00             0.06                 1.32
# 4                        -0.07             0.08                 1.31
# ..                         ...              ...                  ...
# 90                         NaN              NaN                  NaN
# 91                         NaN              NaN                  NaN
# 92                         NaN              NaN                  NaN
# 93                         NaN              NaN                  NaN
# 94                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #2  Acceleration (m/s²) Run #2  Time (s) Run #3  \
# 0                     NaN                         NaN             0.00
# 1                   -0.35                         NaN             0.02
# 2                   -0.46                       -3.63             0.04
# 3                   -0.50                       -1.46             0.06
# 4                   -0.47                       -0.73             0.08
# ..                    ...                         ...              ...
# 90                    NaN                         NaN              NaN
# 91                    NaN                         NaN              NaN
# 92                    NaN                         NaN              NaN
# 93                    NaN                         NaN              NaN
# 94                    NaN                         NaN              NaN
#
#     Position (m) Run #3  ...  Velocity (m/s) Run #8  \
# 0                  1.32  ...                    NaN
# 1                  1.30  ...                   0.30
# 2                  1.31  ...                   0.26
# 3                  1.31  ...                   0.08
# 4                  1.30  ...                  -0.19
# ..                  ...  ...                    ...
# 90                  NaN  ...                    NaN
# 91                  NaN  ...                    NaN
# 92                  NaN  ...                    NaN
# 93                  NaN  ...                    NaN
# 94                  NaN  ...                    NaN
#
#     Acceleration (m/s²) Run #8  Time (s) Run #9  Position (m) Run #9  \
# 0                          NaN             0.00                 1.39
# 1                          NaN             0.02                 1.39
# 2                        -5.64             0.04                 1.39
# 3                        -8.04             0.06                 1.39
# 4                        -5.48             0.08                 1.38
# ..                         ...              ...                  ...
# 90                         NaN              NaN                  NaN
# 91                         NaN              NaN                  NaN
# 92                         NaN              NaN                  NaN
# 93                         NaN              NaN                  NaN
# 94                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #9  Acceleration (m/s²) Run #9  Time (s) Run #10  \
# 0                     NaN                         NaN              0.00
# 1               -0.000827                         NaN              0.02
# 2               -0.040000                       -2.27              0.04
# 3               -0.090000                       -2.15              0.06
# 4               -0.130000                       -0.97              0.08
# ..                    ...                         ...               ...
# 90                    NaN                         NaN               NaN
# 91                    NaN                         NaN               NaN
# 92                    NaN                         NaN               NaN
# 93                    NaN                         NaN               NaN
# 94                    NaN                         NaN               NaN
#
#     Position (m) Run #10  Velocity (m/s) Run #10  Acceleration (m/s²) Run #10
# 0                   1.35                     NaN                          NaN
# 1                   1.35                    0.06                          NaN
# 2                   1.35                    0.02                        -2.52
# 3                   1.34                   -0.04                        -3.46
# 4                   1.35                   -0.16                        -2.35
# ..                   ...                     ...                          ...
# 90                   NaN                     NaN                          NaN
# 91                   NaN                     NaN                          NaN
# 92                   NaN                     NaN                          NaN
# 93                   NaN                     NaN                          NaN
# 94                   NaN                     NaN                          NaN
#
# [95 rows x 40 columns]

# %% [markdown]
# 4. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.  You **should not** manually adjust the content of the `data_df` for each run.
# 5. Display the content of `data_df`

# %%
# Your code for steps 4 and 5 go here:


time_data_df = second_experiment_df[[f'Time (s) Run #{i}' for i in range(1, 11)]] 
position_data_df = second_experiment_df[[f'Position (m) Run #{j}' for j in range(1, 11)]]

data_df = pd.concat([time_data_df, position_data_df], axis = 1)

data_df.dropna(inplace = True)

data_df
# Out:
#     Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 59             1.18             1.18             1.18             1.18
# 60             1.20             1.20             1.20             1.20
# 61             1.22             1.22             1.22             1.22
# 62             1.24             1.24             1.24             1.24
# 63             1.26             1.26             1.26             1.26
#
#     Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 59             1.18             1.18             1.18             1.18
# 60             1.20             1.20             1.20             1.20
# 61             1.22             1.22             1.22             1.22
# 62             1.24             1.24             1.24             1.24
# 63             1.26             1.26             1.26             1.26
#
#     Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0              0.00              0.00                 1.23
# 1              0.02              0.02                 1.21
# 2              0.04              0.04                 1.20
# 3              0.06              0.06                 1.19
# 4              0.08              0.08                 1.17
# ..              ...               ...                  ...
# 59             1.18              1.18                 0.12
# 60             1.20              1.20                 0.13
# 61             1.22              1.22                 0.14
# 62             1.24              1.24                 0.12
# 63             1.26              1.26                 0.11
#
#     Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                  1.34                 1.32                 1.28
# 1                  1.34                 1.30                 1.28
# 2                  1.33                 1.31                 1.28
# 3                  1.32                 1.31                 1.30
# 4                  1.31                 1.30                 1.29
# ..                  ...                  ...                  ...
# 59                 0.32                 0.25                 0.44
# 60                 0.30                 0.23                 0.41
# 61                 0.28                 0.20                 0.39
# 62                 0.26                 0.18                 0.37
# 63                 0.24                 0.16                 0.34
#
#     Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                  1.18                 1.45                 1.38
# 1                  1.17                 1.43                 1.38
# 2                  1.15                 1.42                 1.38
# 3                  1.13                 1.43                 1.38
# 4                  1.12                 1.42                 1.37
# ..                  ...                  ...                  ...
# 59                 1.37                 0.52                 0.64
# 60                 1.40                 0.50                 0.62
# 61                 1.34                 0.48                 0.60
# 62                 1.35                 0.46                 0.59
# 63                 1.30                 0.44                 0.56
#
#     Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                  1.33                 1.39                  1.35
# 1                  1.33                 1.39                  1.35
# 2                  1.35                 1.39                  1.35
# 3                  1.35                 1.39                  1.34
# 4                  1.35                 1.38                  1.35
# ..                  ...                  ...                   ...
# 59                 0.44                 0.57                  0.48
# 60                 0.42                 0.55                  0.46
# 61                 0.40                 0.53                  0.43
# 62                 0.38                 0.51                  0.41
# 63                 0.36                 0.49                  0.39
#
# [64 rows x 20 columns]

# %% [markdown]
# 6. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include the curved data that transitions into a drop in position.  You should only keep about 0.5 to 1 second of the roughly constant position values before the drop of position takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
#
# 7. Store your clean data into a new DataFrame called `clean_df`.
# 8. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 9. Write this to a new .csv file called `"clean_data_single_filter.csv"`.

# %%
# Your code for steps 6-9 go here:

# step 6

cleaned_data = {}

for j in range(1, 11):
    drop_indices = [0, 1, 2, 3]

    position_col = f'Position (m) Run #{j}'
    

    for i in range(35, len(data_df[position_col]) - 1):
        if data_df[position_col].iloc[i + 1] > data_df[position_col].iloc[i]:
            drop_indices.extend((range(i, min(63, len(data_df[position_col])))))
    

# step 7 
      
    clean_data = data_df[position_col].drop(index = set(drop_indices), errors='ignore').drop_duplicates()
    cleaned_data[position_col] = clean_data

all_clean_data = pd.DataFrame(cleaned_data)

all_clean_data

# step 8 

clean_df = pd.concat([time_data_df.shift(4), all_clean_data], axis = 1)

clean_df.drop([0, 1, 2, 3], inplace = True)

clean_df = clean_df[:64]

clean_df

# step 9 

clean_df.to_csv("clean_data_single_filter.csv", index = False)

# %% [markdown]
# 10. Plot the data using `matplotlib` from all 10 runs as scatter plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.
# - scale the size of the points so that they are not too big.
# Note that you should automate the process of plotting the 10 graphs.
#
# 11. Take the last 0.5 to 1 second of the x-values in your 10 runs, and draw a line of best fit on all your 10 graphs.

# %%
# Your code for steps 10-11 go here:
colors = ['blue', 'yellow', 'red', 'green', 'purple', 'orange', 'black', 'grey', 'pink', 'lime']
for i in range(1, 11):
    xpoints = clean_df[f'Time (s) Run #{i}']
    ypoints = clean_df[f'Position (m) Run #{i}']
    plt.scatter(xpoints, ypoints, s = 7)
    
    limiter = (xpoints >= 0.5) & (xpoints <= 1)

    x_fit_points = xpoints[limiter]
    y_fit_points = ypoints[limiter]

    
    a, b = np.polyfit(x_fit_points, y_fit_points, 1) 
    x_fit = np.linspace(0.5 , 1, 100)
    y_fit = a * x_fit + b 


    plt.plot(x_fit, y_fit, color = colors[i - 1], label = f'Run #{i}')
    
    
    plt.xlim(0, 1.25)
    plt.ylim(0, 2)
    plt.xlabel('Time (s)')
    plt.ylabel('Position (m)')
    plt.legend()

# %% [markdown]
# ### ${\color{green} \text{Submit your work to moodle and git for Part 1 before moving to Part 2}}$

# %% [markdown]
# ## Part 2: experiment with multiple coffee filters, 10 runs
# **Part 2 DUE DATE: Friday, February 14 at 20:00**
#
# **Part 2 is worth 40% of Assignment #1**
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$.  Make sure to not delete or overwrite any files during your previous submissions.
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - late submissions of Part 2 will receive a grade of 0.
#
#
# #### Instructions for Part 2:

# %% [markdown]
# 1. Read  your .csv file that has the data of filters of varying mass into a DataFrame `df`.
# 3. Display the content of the DataFrame to the screen

# %%
# Your code for steps 1 and 2 go here:

first_experiment_df = pd.read_csv('Coffee Filter 1.csv')

first_experiment_df

# Since we deleted the first run during the experiment, the runs are labelled from 2 to 11 instead of from 1 to 10.
# Out:
#     Time (s) Run #2  Position (m) Run #2  Velocity (m/s) Run #2  \
# 0              0.00                 1.47                    NaN
# 1              0.02                 1.48                  -0.45
# 2              0.04                 1.45                  -0.20
# 3              0.06                 1.46                  -0.21
# 4              0.08                 1.46                  -0.22
# ..              ...                  ...                    ...
# 89              NaN                  NaN                    NaN
# 90              NaN                  NaN                    NaN
# 91              NaN                  NaN                    NaN
# 92              NaN                  NaN                    NaN
# 93              NaN                  NaN                    NaN
#
#     Acceleration (m/s²) Run #2  Time (s) Run #3  Position (m) Run #3  \
# 0                          NaN             0.00                 1.40
# 1                          NaN             0.02                 1.39
# 2                         6.06             0.04                 1.36
# 3                         0.51             0.06                 1.34
# 4                        -1.39             0.08                 1.32
# ..                         ...              ...                  ...
# 89                         NaN              NaN                  NaN
# 90                         NaN              NaN                  NaN
# 91                         NaN              NaN                  NaN
# 92                         NaN              NaN                  NaN
# 93                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #3  Acceleration (m/s²) Run #3  Time (s) Run #4  \
# 0                     NaN                         NaN             0.00
# 1                   -0.94                         NaN             0.02
# 2                   -1.07                       -3.08             0.04
# 3                   -1.06                       -3.74             0.06
# 4                   -1.09                       -7.69             0.08
# ..                    ...                         ...              ...
# 89                    NaN                         NaN              NaN
# 90                    NaN                         NaN              NaN
# 91                    NaN                         NaN              NaN
# 92                    NaN                         NaN              NaN
# 93                    NaN                         NaN              NaN
#
#     Position (m) Run #4  ...  Velocity (m/s) Run #9  \
# 0                  1.42  ...                    NaN
# 1                  1.43  ...                   0.01
# 2                  1.43  ...                   0.05
# 3                  1.41  ...                   0.14
# 4                  1.40  ...                   0.04
# ..                  ...  ...                    ...
# 89                  NaN  ...                    NaN
# 90                  NaN  ...                    NaN
# 91                  NaN  ...                    NaN
# 92                  NaN  ...                    NaN
# 93                  NaN  ...                    NaN
#
#     Acceleration (m/s²) Run #9  Time (s) Run #10  Position (m) Run #10  \
# 0                          NaN              0.00                  1.34
# 1                          NaN              0.02                  1.35
# 2                         3.01              0.04                  1.35
# 3                        -0.34              0.06                  1.36
# 4                        -2.62              0.08                  1.35
# ..                         ...               ...                   ...
# 89                         NaN               NaN                   NaN
# 90                         NaN               NaN                   NaN
# 91                         NaN               NaN                   NaN
# 92                         NaN               NaN                   NaN
# 93                         NaN               NaN                   NaN
#
#     Velocity (m/s) Run #10  Acceleration (m/s²) Run #10  Time (s) Run #11  \
# 0                      NaN                          NaN              0.00
# 1                     0.07                          NaN              0.02
# 2                     0.10                        -2.10              0.04
# 3                    -0.01                        -4.60              0.06
# 4                    -0.11                        -6.02              0.08
# ..                     ...                          ...               ...
# 89                     NaN                          NaN              1.78
# 90                     NaN                          NaN              1.80
# 91                     NaN                          NaN              1.82
# 92                     NaN                          NaN              1.84
# 93                     NaN                          NaN              1.86
#
#     Position (m) Run #11  Velocity (m/s) Run #11  Acceleration (m/s²) Run #11
# 0                   1.36                     NaN                          NaN
# 16                 0.85                 1.28                 1.47
# 17                 0.80                 1.21                 1.44
# 18                 0.75                 1.18                 1.41
# 19                 0.69                 1.14                 1.39
# 20                 0.64                 1.10                 1.37
# 21                 0.58                 1.06                 1.33
# 22                 0.53                 1.02                 1.29
# 23                 0.47                 0.98                 1.26
# 24                 0.41                 0.93                 1.23
# 25                 0.36                 0.89                 1.20
# 26                 0.30                 0.84                 1.15
# 27                 0.24                 0.80                 1.11
# 28                 0.18                 0.74                 1.07
# 29                 0.12                 0.69                 1.03
# 30                 0.13                 0.64                 0.99
# 31                 0.00                 0.59                 0.95
# 32                 0.00                 0.55                 0.90
# 33                 0.00                 0.48                 0.86
# 34                 0.00                 0.42                 0.81
# 35                 1.42                 0.37                 0.76
# 36                 1.42                 0.31                 0.71
# 37                 1.42                 0.25                 0.66
# 38                 1.42                 0.19                 0.61
# 39                 1.42                 0.13                 0.56
# 40                 1.42                 0.13                 0.51
# 41                 1.42                 0.00                 0.46
# 42                 1.42                 0.00                 0.41
# 43                 1.42                 0.00                 0.35
# 44                 1.42                 0.00                 0.30
#
#     Position (m) Run #6  Position (m) Run #7  Position (m) Run #8  \
# 0                  1.35                 1.38                 1.40
# 1                  1.34                 1.36                 1.40
# 2                  1.31                 1.34                 1.40
# 3                  1.29                 1.32                 1.40
# 4                  1.27                 1.30                 1.40
# 5                  1.24                 1.28                 1.40
# 6                  1.21                 1.26                 1.40
# 7                  1.18                 1.23                 1.41
# 8                  1.15                 1.20                 1.39
# 9                  1.11                 1.17                 1.40
# 10                 1.08                 1.13                 1.39
# 11                 1.04                 1.10                 1.41
# 12                 1.00                 1.06                 1.38
# 13                 0.96                 1.08                 1.37
# 14                 0.92                 0.99                 1.35
# 15                 0.88                 0.96                 1.33
# 16                 0.84                 0.92                 1.31
# 17                 0.80                 0.89                 1.29
# 18                 0.76                 0.84                 1.26
# 19                 0.71                 0.80                 1.23
# 20                 0.66                 0.76                 1.21
# 21                 0.62                 0.71                 1.18
# 22                 0.57                 0.67                 1.15
# 23                 0.52                 0.62                 1.12
# 24                 0.47                 0.58                 1.09
# 25                 0.42                 0.53                 1.06
# 26                 0.36                 0.49                 1.02
# 27                 0.31                 0.44                 0.99
# 28                 0.26                 0.39                 0.95
# 29                 0.21                 0.35                 0.92
# 30                 0.15                 0.30                 0.88
# 31                 0.09                 0.25                 0.84
# 32                 2.60                 0.20                 0.81
# 33                 3.16                 0.16                 0.77
# 34                 1.37                 0.11                 0.72
# 35                 1.36                 1.42                 0.68
# 36                 1.39                 1.46                 0.64
# 37                 1.39                 1.38                 0.60
# 38                 1.40                 1.38                 0.56
# 39                 1.38                 1.38                 0.52
# 40                 1.36                 1.38                 0.48
# 41                 1.37                 1.38                 0.43
# 42                 1.36                 1.38                 0.39
# 43                 1.37                 1.38                 0.35
# 44                 1.36                 1.38                 0.31
#
#     Position (m) Run #9  Position (m) Run #10  Position (m) Run #11
# 0                  1.34                  1.34                  1.36
# 1                  1.34                  1.35                  1.36
# 2                  1.34                  1.35                  1.36
# 3                  1.34                  1.36                  1.37
# 4                  1.35                  1.35                  1.36
# 5                  1.35                  1.35                  1.37
# 6                  1.34                  1.34                  1.36
# 7                  1.35                  1.33                  1.37
# 8                  1.34                  1.32                  1.37
# 9                  1.34                  1.30                  1.39
# 10                 1.34                  1.30                  1.34
# 11                 1.36                  1.28                  1.33
# 12                 1.32                  1.27                  1.32
# 13                 1.30                  1.25                  1.30
# 14                 1.28                  1.22                  1.30
# 15                 1.28                  1.20                  1.28
# 16                 1.26                  1.18                  1.27
# 17                 1.23                  1.16                  1.25
# 18                 1.22                  1.14                  1.24
# 19                 1.18                  1.11                  1.23
# 20                 1.15                  1.10                  1.22
# 21                 1.14                  1.07                  1.20
# 22                 1.09                  1.04                  1.19
# 23                 1.12                  1.02                  1.17
# 24                 1.06                  0.99                  1.16
# 25                 1.02                  0.96                  1.15
# 26                 0.98                  0.93                  1.13
# 27                 0.95                  0.91                  1.11
# 28                 0.92                  0.88                  1.09
# 29                 0.88                  0.85                  1.07
# 30                 0.85                  0.82                  1.06
# 31                 0.82                  0.80                  1.04
# 32                 0.78                  0.76                  1.03
# 33                 0.76                  0.73                  1.01
# 34                 0.72                  0.70                  0.99
# 35                 0.69                  0.68                  0.97
# 36                 0.65                  0.65                  0.95
# 37                 0.61                  0.62                  0.94
# 38                 0.58                  0.59                  0.92
# 39                 0.54                  0.56                  0.90
# 40                 0.51                  0.53                  0.88
# 41                 0.47                  0.50                  0.86
# 42                 0.44                  0.47                  0.84
# 43                 0.40                  0.44                  0.83
# 44                 0.37                  0.41                  0.81

# %% [markdown]
# 5. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include only the bit where a drop in position starts.  You should not include any constant position values before the drop of positions takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
# 6. Store your clean data into a new DataFrame called `clean_df`.
# 7. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 8. Write this to a new .csv file called `"clean_data_multiple_filter.csv"`.

# %%
# Your code for steps 5-8 go here:

# step 5

cleaned_data = {}

for j in range(2, 12):
    drop_indices = [0, 1, 2, 3]

    position_col = f'Position (m) Run #{j}'
    

    for i in range(35, len(data_df[position_col]) - 1):
        if data_df[position_col].iloc[i + 1] > data_df[position_col].iloc[i]:
            drop_indices.extend((range(i, min(63, len(data_df[position_col])))))
    

# step 6
      
    clean_data = data_df[position_col].drop(index = set(drop_indices), errors='ignore').drop_duplicates()
    cleaned_data[position_col] = clean_data

all_clean_data = pd.DataFrame(cleaned_data)

all_clean_data

# step 7

clean_df = pd.concat([time_data_df.shift(4), all_clean_data], axis = 1)

clean_df.drop([0, 1, 2, 3], inplace = True)

clean_df = clean_df[:70]


# this is some extra cleaning made for the runs 5 and 6

clean_df['Position (m) Run #6'] = clean_df['Position (m) Run #6'].drop(list(range(32, 45)))

clean_df.fillna({'Position (m) Run #5' : 1.53}, inplace = True)

clean_df['Position (m) Run #5'] = clean_df['Position (m) Run #5'].drop(list(range(45, 74)))

clean_df['Position (m) Run #5']



# step 8

clean_df.to_csv("clean_data_multiple_filter.csv", index = False)

# %% [markdown]
# 9. Plot the data from all 10 runs as line plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.

# %%
# Your code for step 9 goes here:

for i in range(2, 12):
    xpoints = clean_df[f'Time (s) Run #{i}']
    ypoints = clean_df[f'Position (m) Run #{i}']
    plt.plot(xpoints, ypoints, label = f'Run #{i}')

    plt.xlim(0, 1.5)
    plt.ylim(0, 2)
    plt.xlabel('Time (s)')
    plt.ylabel('Position (m)')
    plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

grades_df = pd.read_csv('Student_Grades.csv')

grades_df
# Out:
#     Hours  Practice  TeamWork   MidTerm  FinalExam  Scores Grade  MidTerm
# 0     2.5       0.5       0.0       2.0        2.3    21.0     C      NaN
# 1     5.1       1.5       0.5       4.0        4.9    47.0     B      NaN
# 2     3.2       1.0       0.5       3.0        2.9    27.0     C      NaN
# 3     8.5       3.7       1.2       7.0        7.7    75.0     A      NaN
# 4     3.5       1.2       0.3       3.0        3.2    30.0     C      NaN
# 5     1.5       0.2       0.0       2.0        2.2    20.0     C      NaN
# 6     9.2       4.8       3.0       8.0        9.0    88.0     A      NaN
# 7     5.5       3.2       2.0       6.0        6.2    60.0     B      NaN
# 8     8.3       5.1       3.5       8.0        8.3    81.0     A      NaN
# 9     2.7       1.5       0.0       3.0        2.7    25.0     C      NaN
# 10    7.7       4.9       4.5       8.0        8.7    85.0     A      NaN
# 11    5.9       3.1       2.1       6.0        6.4    62.0     A      NaN
# 12    4.5       2.8       1.0       4.0        4.3    41.0     B      NaN
# 13    3.3       2.2       1.1       4.0        4.4    42.0     B      NaN
# 14    1.1       1.1       0.0       2.0        1.9    17.0     C      NaN
# 15    8.9       6.2       6.0       9.0        9.7    95.0     A      NaN
# 16    2.5       1.6       1.0       3.0        3.2    30.0     C      NaN
# 17    1.9       0.9       0.5       2.0        2.6    24.0     C      NaN
# 18    6.1       2.0       3.2       6.0        6.9    67.0     A      NaN
# 19    7.4       2.5       3.0       7.0        7.1    69.0     A      NaN
# 20    2.7       3.0       1.2       3.0        3.2    30.0     C      NaN
# 21    4.8       2.9       2.1       5.0        5.6    54.0     B      NaN
# 22    3.8       2.2       0.3       3.0        3.7    35.0     B      NaN
# 23    6.9       5.1       3.8       7.0        7.8    76.0     A      NaN
# 24    7.8       5.8       4.5       8.0        8.8    86.0     A      NaN
# 25    NaN       NaN       NaN       NaN        NaN     NaN   NaN      NaN
# 26    8.1       NaN       NaN       NaN        3.8    25.5     A      7.4
# 27    0.6       NaN       NaN       NaN        6.8     6.0     C      1.5
# 28    8.8       NaN       NaN       NaN        9.6    20.2     F      7.8
# 29    8.5       NaN       NaN       NaN        8.8    92.3     F      4.6
# 30    2.3       NaN       NaN       NaN        2.6    65.4     B      3.3
# 31    3.1       NaN       NaN       NaN        8.8    88.5     D      7.8
# 32    5.5       NaN       NaN       NaN        5.1     9.1     C      3.4
# 33    4.4       NaN       NaN       NaN        9.7    61.5     F      4.4
# 34    5.6       NaN       NaN       NaN        4.3    43.6     E      2.1
# 35    7.1       NaN       NaN       NaN        3.3    94.6     F      3.5

# %% [markdown]
# replace the NaN values in the csv file with new values

# %%
# new_df = grades_df.replace(np.nan, 'some value')
# new_df

# grades_df.replace(np.nan, 'some value', inplace = True)
# grades_df.to_csv('Student_Grades.csv', index = False)

# grades_df

# %%
# grades_df.plot(kind = 'scatter', x = 'Hours', y = 'Scores')

grades_df = grades_df.dropna()

xpoints = grades_df['Hours'].to_numpy()
ypoints = grades_df['Scores'].to_numpy()
plt.scatter(xpoints, ypoints, s = 5)
plt.xlabel('Hours dedicated to study')
plt.ylabel('Final grades')

plt.show()

# %%
grades_df[grades_df['Grade'].str.contains('A')]
# Out:
# Empty DataFrame
# Columns: [Hours, Practice, TeamWork,  MidTerm, FinalExam, Scores, Grade, MidTerm]
# Index: []

# %%
grades_df['Scores'].min()
grades_df['Scores'].max()
grades_df['Scores'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Scores, dtype: float64

# %% [markdown]
# - CHange numerical values to strings
# - set index to hours
# - some s;licing
# -some remaming of columns
# -renaming of index columns

# %%
# grades_df['Hours'] = grades_df['Hours'].astype(str)

new_df = grades_df.set_index('Hours').sort_values('Hours')

new_df.loc[1.1]
new_df.loc[1.1:5.5]

new_df2 = grades_df.rename(columns = {'Hours': 'Hours Studied'})

new_df2 = new_df.rename_axis('Hours studied')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sebas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:1698, in pandas._libs.hashtable.Float64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:1722, in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 1.1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       1 # grades_df['Hours'] = grades_df['Hours'].astype(str)
#       3 new_df = grades_df.set_index('Hours').sort_values('Hours')
# ----> 5 new_df.loc[1.1]
#       6 new_df.loc[1.1:5.5]
#       8 new_df2 = grades_df.rename(columns = {'Hours': 'Hours Studied'})
#
# File c:\Users\sebas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\sebas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File c:\Users\sebas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File c:\Users\sebas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File c:\Users\sebas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 1.1

# %% [markdown]
# * loc and iloc

# %%
# get index pf rows where 'Hours' column is equal to 1.1

lst = grades_df.index[grades_df['Hours'] == 2.5].tolist()

print(lst)

index = lst[1]

grades_df.iloc[index]

grades_df.iloc[index:index + 6]
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 7
#       3 lst = grades_df.index[grades_df['Hours'] == 2.5].tolist()
#       5 print(lst)
# ----> 7 index = lst[1]
#       9 grades_df.iloc[index]
#      11 grades_df.iloc[index:index + 6]
#
# IndexError: list index out of range

# %%
new_df
# new_df.loc[1.1:2, ['Midterm', 'FinalExam', 'Scores']]

# grades_df.iloc[[0, 5], 0:4]

# new_df.at[1.1, 'FinalExam']

# new_df.iat[2, 4]
# Out:
#       Practice TeamWork  MidTerm  FinalExam  Scores Grade
# Hours
# 1.1        1.1      0.0      2.0        1.9    17.0     C
# 1.5        0.2      0.0      2.0        2.2    20.0     C
# 1.9        0.9      0.5      2.0        2.6    24.0     C
# 2.5        0.5      0.0      2.0        2.3    21.0     C
# 2.5        1.6      1.0      3.0        3.2    30.0     C
# 2.7        3.0      1.2      3.0        3.2    30.0     C
# 2.7        1.5      0.0      3.0        2.7    25.0     C
# 3.2        1.0      0.5      3.0        2.9    27.0     C
# 3.3        2.2      1.1      4.0        4.4    42.0     B
# 3.5        1.2      0.3      3.0        3.2    30.0     C
# 3.8        2.2      0.3      3.0        3.7    35.0     B
# 4.5        2.8      1.0      4.0        4.3    41.0     B
# 4.8        2.9      2.1      5.0        5.6    54.0     B
# 5.1        1.5      0.5      4.0        4.9    47.0     B
# 5.5        3.2      2.0      6.0        6.2    60.0     B
# 5.9        3.1      2.1      6.0        6.4    62.0     A
# 6.1        2.0      3.2      6.0        6.9    67.0     A
# 6.9        5.1      3.8      7.0        7.8    76.0     A
# 7.4        2.5      3.0      7.0        7.1    69.0     A
# 7.7        4.9      4.5      8.0        8.7    85.0     A
# 7.8        5.8      4.5      8.0        8.8    86.0     A
# 8.3        5.1      3.5      8.0        8.3    81.0     A
# 8.5        3.7      1.2      7.0        7.7    75.0     A
# 8.9        6.2      6.0      9.0        9.7    95.0     A
# 9.2        4.8      3.0      8.0        9.0    88.0     A

# %% [markdown]
# write a snippet of code that returns the minimum value in the 'Scores' column.

# %% [markdown]
# # Regression Fit

# %% [markdown]
# # at, iat and slicing

# %%
plt.scatter(xpoints, ypoints, s = 8)
plt.xlabel('Hours spent studying')
plt.ylabel('Score')


# create a polynomial function

# coeff = np.polyfit(xpoints, ypoints, deg = 1)

 #best_fit_function = np.poly1d(coeff)

#plt.plot(xpoints, best_fit_function(xpoints), label = 'Regression fit', color = 'red')

#plt.legend()

#plt.show()

#print(coeff)

b, a = np.polyfit(xpoints, ypoints, deg = 1) # b = slope, a = y-intercept

xseq = np.linspace(0, 10) # np.linspace(5, 9)

plt.plot(xseq, b * xseq + a, c = 'red')

plt.show()

print(f'slope is: {b}')
print(f'intercept is: {a}')
# Out:
# slope is: 9.775803390787472
# intercept is: 2.48367340537318
